# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Cars93 data
# In this lab, we would like to explore data about 93 number of vehicles.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 0      102.0   68.0         37.0           26.5           NaN  2705.0
# 1      115.0   71.0         38.0           30.0          15.0  3560.0
# 2      102.0   67.0         37.0           28.0          14.0  3375.0
# 3      106.0    NaN         37.0           31.0          17.0  3405.0
# 4      109.0   69.0         39.0           27.0          13.0  3640.0
#
#     Origin           Make
# 0  non-USA  Acura Integra
# 1  non-USA   Acura Legend
# 2  non-USA        Audi 90
# 3  non-USA       Audi 100
# 4  non-USA       BMW 535i
#
# [5 rows x 27 columns]

# %% [markdown]
# # Matplotlib
# Please refer the [official doc](https://matplotlib.org/) or following [article](https://www.machinelearningplus.com/plots/matplotlib-tutorial-complete-guide-python-plot-examples/) for further detailed tricks.

# %% [markdown]
# **[TODO]** Draw *pie chart* of `Type` (hint, refer pandas'  [`.value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) method and the [article](https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f) about *pie chart*).

# %%
typeCount = df.Type.value_counts()
fig, ax = plt.subplots(figsize=(6,6))
ex = [0.05,0.05,0.05,0.05,0.05,0.05]

ax.pie(typeCount,
       labels=df.Type.value_counts().index,
       autopct='%.1f%%',
       pctdistance=0.85,
       explode=ex)

#draw white circle in the middle
centre_circle = plt.Circle((0,0),0.70,color='white')
ax.add_artist(centre_circle)

plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# Please refer the [official doc](https://seaborn.pydata.org/).

# %% [markdown]
# **[TODO]** Plot *boxplot* which comparing the `Price` according to `Type`. The plot must satisify following conditions.
#  * nested grouping within additional categorical variable, `Origin`
#  * using `Greys` color palette

# %%
fig, ax = plt.subplots(figsize=(9,6))
sns.boxplot(x="Type",
            y="Price",
            hue="Origin",
            palette=sns.color_palette("Greys", 2),
            data=df)
plt.show()

# %% [markdown]
# **[TODO]** Plot *pair plot*. The plot must satisify following conditions.
# * Target variables are `Price`, `MPG.city`,	`MPG.highway`, `Rev.per.mile`.
# * **[Advanced and Optional]** For the non-diagonal plots, add text with pearson's correlation value. (hint, you should add text manually using iteration)

# %%
targetVar = ['Price', 'MPG.city', 'MPG.highway', 'Rev.per.mile']             

g = sns.pairplot(data=df, vars=targetVar)

corrValue = df[['Price', 'MPG.city', 'MPG.highway', 'Rev.per.mile']].corr().values

for i, (ax, cv) in enumerate(zip(g.axes.flat, corrValue.flatten())):  
    if(cv!=1):
        ax.annotate("Corr: "+str(np.round(cv,2)), xycoords=ax.transAxes, xy=(0.3, 0.8))
    
plt.show()

# %% [markdown]
# # Plotly

# %% [markdown]
# **[TODO]** Plot *density contour plot* and deploy the dashboard.
# * The *density contour plot* should show relationship between `Price` and user choosen variable among `MPG.city`, `MPG.highway`, `Rev.per.mile`.
#
# (please refer [official doc](https://plotly.com/python/2d-histogram-contour/) about *density contour plot*)

# %%
# install packages
# !pip install dash
# !pip install jupyter_dash
# Out:
# Collecting dash
#   Downloading dash-2.0.0-py3-none-any.whl (7.3 MB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from dash) (5.3.0)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0.tar.gz (3.4 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0.tar.gz (3.8 kB)
# Collecting flask-compress
#   Downloading Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\dilab\anaconda3\lib\site-packages (from dash) (1.1.2)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0.tar.gz (3.4 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\dilab\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\dilab\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\dilab\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\dilab\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dilab\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: six in c:\users\dilab\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dilab\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
# Building wheels for collected packages: dash-core-components, dash-html-components, dash-table
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3803 sha256=257656627c66ad57ff542d9751e6a9533d13ff83904e849bb7f91468fb559a7d
#   Stored in directory: c:\users\dilab\appdata\local\pip\cache\wheels\52\e4\f3\16724791571a955a46d54650510c98c04ab7d339626aee27cc
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4071 sha256=6d646a0900a2833ab39605c81c2f9ef42a5d9c28ae9c40cdf3b72bbc7835def5
#   Stored in directory: c:\users\dilab\appdata\local\pip\cache\wheels\73\d8\8d\92f612c03c895f19bcc56a6c54be7bb41aaa698012a5624f60
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-5.0.0-py3-none-any.whl size=3896 sha256=e65cf3254a84f017d2c094347ac54fa54669f4b97b427d9d240de7533e0aee5c
#   Stored in directory: c:\users\dilab\appdata\local\pip\cache\wheels\a6\fb\f5\4adf241f384634f52028f15eab6a325e77b8766a0a00816bbf
# Successfully built dash-core-components dash-html-components dash-table
# Installing collected packages: brotli, flask-compress, dash-table, dash-html-components, dash-core-components, dash
# Successfully installed brotli-1.0.9 dash-2.0.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.10.1
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: dash in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (2.0.0)
# Collecting ansi2html
#   Downloading ansi2html-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipython in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: requests in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: retrying in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: flask in c:\users\dilab\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\dilab\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.3.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: click>=5.1 in c:\users\dilab\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\dilab\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\dilab\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\dilab\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dilab\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: six in c:\users\dilab\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dilab\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\dilab\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\dilab\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\dilab\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\dilab\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: colorama in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: pygments in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: pickleshare in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: decorator in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: backcall in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\dilab\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\dilab\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\dilab\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\dilab\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\dilab\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\dilab\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\dilab\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dilab\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dilab\anaconda3\lib\site-packages (from requests->jupyter_dash) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dilab\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\dilab\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dilab\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Installing collected packages: ansi2html, jupyter-dash
# Successfully installed ansi2html-1.6.0 jupyter-dash-0.4.0

# %%
import dash
from dash import html
import plotly.graph_objects as go
from dash import dcc
import plotly.express as px
from dash.dependencies import Input, Output

from jupyter_dash import JupyterDash

# %%
# Load Dash App
app = JupyterDash()

# Define App
app.layout = html.Div(id = 'parent', 
                      children = [html.H1(id = 'H1', children = 'Cas93 Dashboard', style = {'textAlign':'center', 'marginTop':40, 'marginBottom':40}),
                                  dcc.Dropdown(
                                      id='dropdown',
                                      options=[
                                          {'label': 'MPG.city', 'value': 'MPG.city'}, 
                                          {'label': 'MPG.highway', 'value': 'MPG.highway'}, 
                                          {'label': 'Rev.per.mile', 'value': 'Rev.per.mile'}
                                      ],
                                      value = 'MPG.city'
                                  ),
                                  dcc.Graph(id = 'plot')
                                  ])

# Define callback decorator and it's function    
@app.callback(Output(component_id='plot', component_property= 'figure'),
              [Input(component_id='dropdown', component_property= 'value')])
def graph_update(dropdown_value):
    print(dropdown_value)
    fig = px.density_contour(df, x="Price", y=dropdown_value, marginal_x="histogram", marginal_y="histogram")

    return fig  

if __name__ == '__main__': 
    app.run_server()
# Out:
# Dash app running on http://127.0.0.1:8050/
# MPG.city
# MPG.city
# MPG.city
# MPG.city
# None
# MPG.city
# None
